# %% [markdown]
# ## Final Exam/Project ( 45 points)

# %% [markdown]
# #### Submit your final project as a. ipynb file. Use the format 'Final_project_Team_1.ipynb'. Run your code and then submit the jupyter notebook. If there are no comments/markdown describing what you have done, your work will not be graded. Follow the code of conduct.

# %% [markdown]
# ##### The dataset you used in homework 4 comprises measurements from an array of 10 metal oxide semiconductor sensors, capturing the responses to 6 different gases. The gases were present at extremely low concentrations, measured in parts per billion (ppb). This [research study](https://ieeexplore.ieee.org/document/10057438/metrics#metrics) implemented different classification methods and came up with their own feature selection and ensemble method for classification. Go through that paper and carry out the following:

# %% [markdown]
# ##### Q1. Present your work in HW 4 in the context of the paper (broadly going over the Abstract and Introduction).   (10 points)
#
# **Note:** These presentations will happen in class on March 10th and March 12th over zoom. All teams will upload presentations before class on March 10 to be fair to everybody. Each team will have 10 mins to present (leave one min for Q&A).

# %% [markdown]
# specifically talk about the overall approach you followed and the paper followed

# %% [markdown]
# ##### Q2. Implement the classification task by utilizing SVM classification and doing hyperparameter tuning as done in the paper. Output the best accuracy you get on the test set. (5 points)
#
# **Note**: Use the same data splitting/cross validation strategy as described in the paper.

# %% [markdown]
# ##### Q3. Carry out your own feature selection by randomly sampling at an interval of 64 in the 900 timepoints dataset for each sensor. You will do this for all 10 sensors and  repreat this step 2500 times to get 500 such feature subsets. This is somewhat similar to the strategy followed in the paper. Using these subsets, train an ensemble of SVM models (choose the best model from Q2 and use majority voting) and report the test accuracy(10 points)

# %% [markdown]
# ##### Q4. Implement the best SVM model in Q2 on the feature subset data provided to you (features.csv). These are the features that were extracted in the study and check what accuracy are you getting. (5 points)

# %% [markdown]
# ##### Q5. Implement the multilayer perceptron model using lbfs solver and optimize for the number of hidden layers, neurons and L2 regularization. Report the best accuracy (10 points)

# %% [markdown]
# ##### Q6. Summarize the paper and your work (5 points)

# %% [markdown]
# specifically talk about ensemble learning and how has the paper utilized it
